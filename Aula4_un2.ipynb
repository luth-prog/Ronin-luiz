# %% [markdown]
# <a href="https://colab.research.google.com/github/luth-prog/my_repository/blob/main/Aula4_un2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#primeira modo
import math

math.sqrt(9)
#math.log2(1024)
#math.cos(45)
# Out:
# 3.0

# %%
#segunda modo
import math as m

m.sqrt(9)
#m.log2(1024)
#m.cos(45)

# %%
#terceiro modo
from math import sqrt, log2, cos

sqrt(9)
#log2(1024)
#cos(45)

# %%
import matplotlib.pyplot as plt

# Dados
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

# Criar um grafico de linha
plt.plot(x, y)

# Adicionar rotulos aos eixos
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

# Adicionar um titulo ao gráfico
plt.title('Exemplo de Grafico de Linha')

# Exibir grafico
plt.show()

# %%
# Atividade
# Importando bibliotecas
import matplotlib.pyplot as plt

#Dados
vendas = [100, 150, 250, 90, 100, 200]
meses = [1, 2, 3, 4, 5, 6]

#semestre1 = vendas[0: 5]
#semestre2 = vendas[6: 11]
#vendas_semestre = [semestre1, semestre2]
#semestres = [1, 2, 3, 4]


# Criando o grafico
plt.bar(meses, vendas)
#plt.bar(semestres, vendas_semestre)

# Nomeando os eixos
plt.xlabel('Meses')
plt.ylabel('Vendas')

#Mostrando o grafico
plt.show()
