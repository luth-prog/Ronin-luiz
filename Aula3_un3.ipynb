# %% [markdown]
# <a href="https://colab.research.google.com/github/luth-prog/my_repository/blob/main/Aula3_un3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Criando uma série a partir da api da selic
df_selic = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.11/dados?formato=json&dataInicial=28/09/2015&dataFinal=28/09/2025')


print(df_selic.info())
print(df_selic)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2510 entries, 0 to 2509
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    2510 non-null   object
#  1   valor   2510 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 39.3+ KB
# None
#             data     valor
# 0     28/09/2015  0.052531
# 1     29/09/2015  0.052531
# 2     30/09/2015  0.052531
# 3     01/10/2015  0.052531
# 4     02/10/2015  0.052531
# ...          ...       ...
# 2505  22/09/2025  0.055131
# 2506  23/09/2025  0.055131
# 2507  24/09/2025  0.055131
# 2508  25/09/2025  0.055131
# 2509  26/09/2025  0.055131
#
# [2510 rows x 2 columns]

# %%
# Verificando a duplicidade de linhas (passo muito importante), utilizando a função drop_duplicates()
df_selic.drop_duplicates(keep='last', inplace=True)
# Mantém o ultimo registro (keep='last')
# Através do parametro (inplace=True), faz com que a manipulação seja salva no DataFrame
# no nosso caso não existe linhas duplicadas

print(df_selic)
# Out:
#             data     valor
# 0     28/09/2015  0.052531
# 1     29/09/2015  0.052531
# 2     30/09/2015  0.052531
# 3     01/10/2015  0.052531
# 4     02/10/2015  0.052531
# ...          ...       ...
# 2505  22/09/2025  0.055131
# 2506  23/09/2025  0.055131
# 2507  24/09/2025  0.055131
# 2508  25/09/2025  0.055131
# 2509  26/09/2025  0.055131
#
# [2510 rows x 2 columns]

# %%
# Adicionando colunas
from datetime import date
from datetime import datetime as dt

data_extracao = date.today()

df_selic['data_extracao'] = data_extracao
df_selic['responsavel'] = "Luiz"

print(df_selic.info())
df_selic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2510 entries, 0 to 2509
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data           2510 non-null   object
#  1   valor          2510 non-null   float64
#  2   data_extracao  2510 non-null   object
#  3   responsavel    2510 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 78.6+ KB
# None
#          data     valor data_extracao responsavel
# 0  28/09/2015  0.052531    2025-09-28        Luiz
# 1  29/09/2015  0.052531    2025-09-28        Luiz
# 2  30/09/2015  0.052531    2025-09-28        Luiz
# 3  01/10/2015  0.052531    2025-09-28        Luiz
# 4  02/10/2015  0.052531    2025-09-28        Luiz

# %%
df_selic.loc[0]
# Out:
# data             28/09/2015
# valor              0.052531
# data_extracao    2025-09-28
# responsavel            Luiz
# Name: 0, dtype: object

# %%
df_selic.loc[[0, 20, 70]]
# Out:
#           data     valor data_extracao responsavel
# 0   28/09/2015  0.052531    2025-09-28        Luiz
# 20  27/10/2015  0.052531    2025-09-28        Luiz
# 70  08/01/2016  0.052531    2025-09-28        Luiz

# %%
df_selic.loc[0]['data']
# Out:
# '28/09/2015'

# %%
df_selic.loc[0]['valor']
# Out:
# np.float64(0.052531)

# %%
teste = df_selic['valor'] < 0.01
print(type(teste))
print(teste)
# Out:
# <class 'pandas.core.series.Series'>
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2505    False
# 2506    False
# 2507    False
# 2508    False
# 2509    False
# Name: valor, Length: 2510, dtype: bool

# %%
# Atividade
import pandas as pd

# Criando um DataFrame com 5 linhas de dados
dados = {
    'nome': ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E'],
    'quantidade de itens comprados': [3, 1, 4, 3, 2],
    'tipo de item': ['Eletronico', 'Vestuário', 'Alimento', 'Eletrônico', 'Alimento'],
    'receita total': [120, 80, 60, 120, 90]
}

df =  pd.DataFrame(dados)

print(df)
# Out:
#         nome  quantidade de itens comprados tipo de item  receita total
# 0  Produto A                              3   Eletronico            120
# 1  Produto B                              1    Vestuário             80
# 2  Produto C                              4     Alimento             60
# 3  Produto D                              3   Eletrônico            120
# 4  Produto E                              2     Alimento             90

# %%
# Duplicando uma linha
df.drop_duplicates(keep='first', inplace=True)
print(df)
# Out:
#         nome  quantidade de itens comprados tipo de item  receita total  \
# 0  Produto A                              3   Eletronico            120
# 1  Produto B                              1    Vestuário             80
# 2  Produto C                              4     Alimento             60
# 3  Produto D                              3   Eletrônico            120
# 4  Produto E                              2     Alimento             90
#
#    preco do item
# 0           40.0
# 1           80.0
# 2           15.0
# 3           40.0
# 4           45.0

# %%
# Calculando a coluna 'preço do item'
df['preco do item'] = df['receita total'] / df['quantidade de itens comprados']

# Solucionando preço do item acima de 50 reais
itens_acima_de_50 = df[df['preco do item'] > 50]

print("Itens acima de 50 reais:")
print(itens_acima_de_50)
# Out:
# Itens acima de 50 reais:
#         nome  quantidade de itens comprados tipo de item  receita total  \
# 1  Produto B                              1    Vestuário             80
#
#    preco do item
# 1           80.0
